# %% [markdown]
# # 测试图片相似度

# %%
sys.path.append("../..")

# %%
from vsearch.video import PaddleFrame
import sys
import cv2 as cv
# Out:
# 最开始 RootPath.output_videos_dir: ../..\static\vsearch-output\videos
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1348/1667984397.py in <module>
# ----> 1 from vsearch.video import PaddleFrame
#       2 import sys
#       3 import cv2 as cv
#
# f:\Document\VSCode\Projects\flask-test\vsearch\video.py in <module>
#      17 # import paddle
#      18
# ---> 19 from . import utils
#      20 from .config import args
#      21 from .sim_v1 import TextSimilarity
#
# f:\Document\VSCode\Projects\flask-test\vsearch\utils.py in <module>
#       9 import numpy as np
#      10 from .config import path
# ---> 11 from .video import Chapter, Video
#      12 from .config import args
#      13 import os
#
# ImportError: cannot import name 'Chapter' from 'vsearch.video' (../..\vsearch\video.py)

# %%
img1 = 'F:\Document\VSCode\Projects\\flask-test\static\\vsearch-output\\test6\\2#2575-2500.png'
img2 = 'F:\Document\VSCode\Projects\\flask-test\static\\vsearch-output\\test6\\2#2625-2600.png'

frame1 = cv.imread(img1)
frame2 = cv.imread(img2)
pf1 = PaddleFrame(2, frame1, 0, '',2)
pf2 = PaddleFrame(2, frame2, 0, '',2)
